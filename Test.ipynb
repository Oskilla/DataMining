# %%
#relance pour le remplacement des auteur restants
import re
import numpy as np
import pandas as pd
import os
import ff
from datetime import datetime

# %%
HPData = pd.read_csv(r'finalHPData.csv')
#Colonne Author
#Certaint auteur n'ont pas été correctement entré dans la table (il y en a environ 2000 dans note échantillons), on va les remplacer par Unknonw author pour le moment
for i in range(len(HPData['Author'])):
    val = HPData.iloc[i]['Author']
    if(val=="reviews"):
        url = HPData['Story_link'][i]
        urlsplit = re.split('/',url)
        id = urlsplit[4]
        a = ff.Story(url,int(id)) # fanfiction API
        try: # certaines fanfiction ne sont plus disponible il est donc impossible de retrouvé l'auteur original
            a.download_data(5) # si la fanfiction n'est plus accessible alors une AttributeErrir ou ReadTimeoutError est levé
            b = a.get_user()
            b.download_data(5)
            print(b.username)
            HPData['Author'][i] = b.username
        except AttributeError:
            HPData['Author'][i] = "Unknown author"
        except ReadTimeoutError:
            HPData['Author'][i] = "Unknown author"
# Out:
# DarylDixon-sgirl1985
# C:\Users\quest\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# Paige0703
# Sostenesto
# Paige0703
# Sostenesto
# Paige0703
# yllwcrd
# Panihi
# TheWrter
# C:\Users\quest\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Anonymous-Wandmaker
# Lunamionny
# Right-What-Is-Wrong
# abovetheserpentine
# LeQuin
# textaman2
# Dellaween
# 22Fahrenheit
# CinderellaAtTheBall
# DarylDixon-sgirl1985
# MoonytheMarauder1
# NeonDomino
# Muffliat0
# SewingSlytherin
# Lomonaaeren
# gryffindormischief
# Windrises
# Ninjasnowflake
# IscreamwillfixIt
# KeepSmiling1
# Sariaa24
# RavieSnake
# Escoger
# SugarcaneSoldier
# LittleSixx
# An-Asian-Guy
# muminSarita
# viviannewriting
# CoconutRadish
# Dellaween
# IscreamwillfixIt
# Mary-J-Anna
# In-Dreams
# SewingSlytherin
# 22Fahrenheit
# Richard-Lovelace
# Muffliat0
# Sostenesto
# HarukaChihiro
# Aludra-Enigma-Prince
# Les-Kinagies
# Les-Kinagies
# Les-Kinagies
# aanchor
# Neevy-Ambr-Du
# Natalie-Annick-Malfoy-Granger
# Gaia-s-melody
# SombraGris
# Plume-de-Pluie
# FandaticForeverAndAlways
# TheLastLynx
# Rasiaa
# 22Fahrenheit
# Sostenesto
# WeLonelyOldSouls
# Muffliat0
# DarylDixon-sgirl1985
# CinderellaAtTheBall
# The-Dark-Warden
# Blainy-Kid
# NelsonBadelson
# morgana-s-mooncalf
# ADabOfBlessings
# Untold-Harmony
# MelCrooks
# Miss-Lefroy-Fraser
# Herochick007
# Dellaween
# BloodyWar2411
# morgana-s-mooncalf
# OctavCat
# Natalie-Annick-Malfoy-Granger
# OctavCat
# IscreamwillfixIt
# Midots
# whitetiger91
# JustPaulInHere
# HanakaLu
# Cassandre-Potter
# Enileme-R
# HecateA
# athenaphoenix17
# Smithback
# athenaphoenix17
# tweety-src-clt9
# DracoNunquamDormiens
# pottermum
# Kerioke
# Swansongs1111
# the8horcrux
# inakindofdaydream
# A-A-Farrow
# DetectiveMinerva
# Lomonaaeren
# Aya-Diefair
# Untold-Harmony
# NuclearNik
# DarcyGreyCoulter
# TheLovelyPatronus
# lyrialoli
# HogwartsPrincess89
# DarylDixon-sgirl1985
# secretfanficlover
# Nova5621
# Mintelle
# Feux-follet
# a-perfect-melody
# White-Eyebrow
# NinjaDevil2000
# tweety-src-clt9
# B-Weasley
# secretfanficlover
# secretfanficlover
# Kou-Shuurei-sama
# E-A-Saint-Mary
# HanakaLu
# Mo-Nighean-Donn
# DelfineNotPadfoot
# pottermum
# Kou-Shuurei-sama
# AutonomousAnonymous
# Cardinal-Rose
# Ammie-Hawk
# Art3misiA
# to-paint-the-unsaid
# petals-to-fish
# thislittlepiggi
# Lulu-Pink
# whitetiger91
# MrsRen
# DramioneShips
# Ribeiro1986
# Wolf-Antlers
# bookloser
# MagicGirlinAMuggleWorld
# BlueWater5
# xelotorix
# kitsune-aux-amandes
# Herochick007
# ECYM
# White-Eyebrow
# MournfulSeverity
# CinderellaAtTheBall
# la-plus-heureuse
# Herochick007
# xxLucindaxx
# ellikanellika
# Jem-Doe
# Grumpr
# TheaLaurel
# claysad
# LoonyLuiny
# allthewaytothegraveyard
# ImHollyBlue
# longdistance
# Herochick007
# CallunaRussell
# Imaginary-Albatross
# PuffleHuff90
# DaughteroftheOneTrueKing
# Kefalion
# celticwitch77
# ViolaMoon
# the-stargate-time-traveller
# Dreamweaver-sQuill
# the-stargate-time-traveller
# SoyBefana
# the-stargate-time-traveller
# The-Hat-Potato
# Marie-Tomas
# Clavyus
# Jess-Lili
# Aya-Diefair
# HecateA
# Realmsmith
# Pokey314
# MoonytheMarauder1
# lannistersdebt
# china4345
# Irene-Garza
# ChocolateCarnival
# Miss-Curie
# DLys
# Cinnamonwildflower
# Sylvyana
# Sylvyana
# Leyrann
# headcanonsandmore
# Vrunetti
# Pruls
# Phosphoros
# Miss-Curie
# Tragedy-girl
# Prongs7777
# GuiltyMe
# ImHollyBlue
# Quall210
# Ayame-Nekura
# DarkEagle69
# AnneliseElla
# NinjaDevil2000
# NinjaDevil2000
# MoonytheMarauder1
# Lostyourmind
# Liesel-Everdeen-freya-uchiha
# Dreamweaver-sQuill
# V-Sourweather
# Little-Miss-Xanda
# tweety-src-clt9
# LadyMiroir
# CinderellaAtTheBall
# lumosmaqixma
# hotwandaction69
# LeeASherlook
# reborn77184
# FiresFromOurHearts
# zugrian
# 0nce-Upon-My-Story
# SiriusMarauderFan
# blackstarlight17
# Kira5Awesome
# LittleSixx
# Aa11yah
# ImHollyBlue
# secretfanficlover
# ImHollyBlue
# Tempest-E-Dashon
# matrixaffiliate
# HecateA
# Neville-Thiccbottom
# scissorluvjw
# DarylDixon-sgirl1985
# WiseGryffindor
# LegilimensKbzd
# Karen-Killa
# MarinersRevenge
# NotSoSirius92
# Moonbeam37
# NotSoSirius92
# NotSoSirius92
# emaginary-doe
# StevenTLawson
# BonnieWolfgang
# continuedinterests
# tweety-src-clt9
# Iris-Butterfly
# Lucy-Pensiveie
# belenpotter24
# Vale-Malfoy-Black
# Les-Kinagies
# idreamofdraco
# LauraUriex
# DarylDixon-sgirl1985
# MirandaSwitch
# Phosphoros
# AliceJeanne
# secretfanficlover
# KrisTerms
# secretfanficlover
# artemisgirl
# claysad
# Caz251
# Lor-tan
# mew-tsubaki
# falling-winter-roses
# hollyhobbit101
# Herochick007
# rezakeene
# B-Weasley
# ginnys01
# AgentOfTheFandoms
# stillplayingpretend
# HuntressSoul
# DarylDixon-sgirl1985
# Morbidmuch
# VerbalScribe
# IRiSEaGLes
# aimeedaralyon
# NewHPwriter
# Fairyglither
# Gajevyaddict
# KeepSmiling1
# HoplessAndWandering
# Mokaji
# DaughteroftheOneTrueKing
# savedprincess85
# DaughteroftheOneTrueKing
# Tasha9315
# FairytalesOfForever
# regulilystan
# Rule23
# Lemniscata
# Tabby-Kitten
# SweetestSerenade
# Mamma-Wolf
# FeeBe
# Always214
# ritsuka10
# ZafiroKristalino
# FoxandFeatheredQuill
# Shychick
# KatieBY
# Hollyshade
# Phosphoros
# Celestia0909
# closetcannons
# Celestia0909
# Bluecookie300
# themadmage
# FlyersGirl1
# Multiverse-0f-Fantasy
# FeeBe
# hananda
# FuryPossessed
# tweety-src-clt9
# WhatIfHP
# Hazuzu
# Lizzie-Brookes
# Jem-Doe
# poisonrationalitie
# lazyweekendmornings
# athenaphoenix17
# DarylDixon-sgirl1985
# FlyersGirl1
# corvusdraconis
# lorbie05
# Alytiger
# a-perfect-melody
# Jonathan-Palmer
# elderfuthark
# Orpheus-Kidwell
# Spontaneous-Pencil
# QuickSilverFox3
# spoopy-rock
# Fishturbine
# AddeyWabbit
# emaginary-doe
# Jem-Doe
# FeeBe
# Kokoro893
# Myobsessivedevotion
# ThatCrazyLeftTwix
# FeeBe
# Liesel-Everdeen-freya-uchiha
# MoonstoneAndStarDust
# mysticalminstrel
# autumn-midnights
# Liesel-Everdeen-freya-uchiha
# Pearl-Gatsby
# AlexandreaLily107
# ZafiroKristalino
# Epeefencer
# Elaysa
# thejilyship
# Chris-Uzumaki-sensei
# Emmabeth27
# LouieLynn22
# livie375
# RachelJMLivingston
# DeodorantSpray
# AliceJeanne
# Yrie-Valk
# MoonytheMarauder1
# ViolaMoon
# AliceJeanne
# messenger-of-home-baked-pie
# irislim
# Aludra-Enigma-Prince
# La-plus-grande-fan-du-38
# geoblock
# ZafiroKristalino
# wintergreen825
# cherrydenny
# jkrowlingreal
# FeeBe
# FeeBe
# yaoigirl22
# TWDCarlGrimes
# BellatrixLestrangey
# little-sis3
# mattchacchin
# Hoodraii
# Myobsessivedevotion
# Elleth-of-Hidden-Lore
# Rinoaebastel
# FredandGeorgeWeasley4life
# Rinoaebastel
# LaurenKane4610
# secretfanficlover
# PFIrisa
# athenaphoenix17
# tweety-src-clt9
# DolphinReader
# xXxVioletSkyxXx
# DarylDixon-sgirl1985
# ravenslight
# madie080802
# BlackAtena66
# Smithback
# demonqueen9
# The-K1D
# Avrisoulle
# DarylDixon-sgirl1985
# CinderellaAtTheBall
# Herochick007
# Flumet
# QuickSilverFox3
# Hazuzu
# AspiringAuthorInTraining
# LittleSixx
# whitetiger91
# Brucasfamily
# CinderellaAtTheBall
# 1986spacekitten
# awanderingwriter
# Kazlerox
# Jem-Doe
# HecateA
# not-snorry
# StevenTLawson
# AnnaleaseTurner
# vixevilcat7
# Carbon-Dated
# MarieKavanagh
# Stereestar
# secretfanficlover
# RayWritesThings
# DarkAngelOfSorrowReturns
# Irene-Garza
# Jem-Doe
# Rule23
# cruisin-for-a-bruisin
# autumn-midnights
# Magical-Malady
# xxxIloveKISSHUxxx
# ImHollyBlue
# Estrella-Blank
# Slytherclaw101
# Miss-Lefroy-Fraser
# Miss-Lefroy-Fraser
# In-Dreams
# Emmabeth27
# Nonbendo
# Priestesses-of-H-I-S-S
# vixevilcat7
# LadyKenz347
# MagicalxMinx
# Micke1988
# Silver-Orbed-Lioness
# LegoKabbit
# NotTooClever
# DarkAngelOfSorrowReturns
# Sonya-Heather-DeVito
# AzaleaBlue
# Likhari
# Jem-Doe
# psc07
# AnneCaterina
# JoanSalvadorKandinski
# FirstSilverKing
# Tooru-Hally-Beelia-FrikiPotter
# NeuroNerd11
# FeeBe
# PhoenixDragon111
# In-Dreams
# Hillnerd
# Herochick007
# absolutefem
# BellatrixLestrangey
# MrsRen
# poisonrationalitie
# Emmeebee
# Herochick007
# HanakaLu
# petals-to-fish
# Eohwel
# Enixking
# amybielby92
# MoonytheMarauder1
# Peter-Tool
# housewifespliffin
# Sirenh00
# Celestia0909
# Armoise-asphodle-cytise-bruyre
# QueenFerza
# slytherin24
# Ro-RoWeasley
# CourtneyEllen
# EscritoraDePocaMonta
# Cailean-Charmeleon
# EscritoraDePocaMonta
# mayawene
# Athenos27
# Ytheheckrtheronly17cherubbooks
# Cowboyhaters93
# HarryPLovecraft
# GimmeThatNightFever
# LycoX
# Xlascivious-XenthusiastX
# DoubleMendez24
# mew-tsubaki
# gryffindormischief
# fizzybubbles13
# LuckyNumeralThirteen
# memgril
# Priestesses-of-H-I-S-S
# HecateA
# secretfanficlover
# secretfanficlover
# Flumet
# KellerTur
# Jemava-S
# secretfanficlover
# tweety-src-clt9
# Rinoaebastel
# Gedankenflug
# Let-sBurnThisGirl
# Tabby-Kitten
# Mrs-Charlie
# DragonLady37
# LadyGreyStallion92
# Destrong
# Smithback
# Drollittle
# Carolyn12
# NatureMan97
# In-Dreams
# DaughterOfScienceAndMagic
# LittleFics
# AntshaLora
# Lady-Lyuva
# Greed720
# the-Azbaban-Dreamer
# GinLyra
# MagicGirlinAMuggleWorld
# Valen-Goncalvez
# PotterFanatic17
# QueenOfTheDreamers87
# potionseagle
# articcat621
# justicerobinson1004gmail-com
# Lor-tan
# DobbyRocksSocks
# MoonytheMarauder1
# ginnys01
# Melancholy-s-Sunshine
# Shibalyfe
# stillplayingpretend
# KatieBY
# Fran-KT
# Janie-ohio
# sea-nymphe
# Maya-L-Roberts
# Ptitemysty
# The-madness-in-me
# Storiesmania
# alyssarey
# Miss-Curie
# Lialee-Ederian
# DaughteroftheOneTrueKing
# TheBlindMusician
# honeysweetcutie
# xxxIloveKISSHUxxx
# GalaxyOwl13
# Mishkin
# MesalinaBlack
# SenLinYu
# madie080802
# Ro-RoWeasley
# LexSnape
# secretfanficlover
# DobbyRocksSocks
# enniferfs
# enniferfs
# Xedra
# Xedra
# athenaphoenix17
# MoonytheMarauder1
# Ingrid-Halloway
# In-Dreams
# Lysore
# Kourtney-Uzu-Yato
# whitetiger91
# midnight-lady-g
# Storiesmania
# hollyhobbit101
# ThePenandtheSword98
# MrsRen
# DarkPrincess1996
# DobbyRocksSocks
# xxDustNight88
# xxDustNight88
# cissymalfoys
# starrnobella
# KingOfJacks
# LadyKenz347
# Jess-Lili
# RhumFramboise
# Cheeky-Slytherin-Lass
# secretfanficlover
# In-Dreams
# Storiesmania
# Amai-Star-of-Darkness
# PlayerPotter
# MarieKavanagh
# tweety-src-clt9
# lannistersdebt
# DarylDixon-sgirl1985
# CinderellaAtTheBall
# Primrue
# ViolaMoon
# WhatComesFromWithin
# MoonytheMarauder1
# forksbluehorse
# AlwaysLupin
# GuiltyMe
# HP-Slash-Luv
# NeonDomino
# Ptitemysty
# ConstructiveRomance
# sphinx01
# secretfanficlover
# Ayolen
# WaitItGetzBetter
# Doristarazona
# tweety-src-clt9
# The-Dragon-Bi
# LeonessaBlue
# huntsmanassassin
# ALRYM
# TheTitaniumSerpent
# Doristarazona
# Goxha
# Libri-Girl
# In-Dreams
# The-Dark-Waltz
# EnchantedPixie495
# UnSinkableGecko
# msmerlin13
# HecateA
# HP-Slash-Luv
# starspangledpumpkin
# Sophisticated-Sage
# MagicGirlinAMuggleWorld
# MarieKavanagh
# SuicidalSpiders
# sarenia
# unablearethelovedtodie
# starspangledpumpkin
# Yut-Taha-Aki
# Theunyieldingman
# slytherin24
# GinLyra
# Untold-Harmony
# June-Lyomi
# secretfanficlover
# DobbyRocksSocks
# Little-Miss-Xanda
# Ocelaw
# Rule23
# DobbyRocksSocks
# TheQuietAwakening
# aedgley
# Cookies-and-Ink
# secretfanficlover
# Spock99
# Anastasija-Deutsch
# SiriusMarauderFan
# Queen-Bookworm-the-First
# JammyWammy
# potionseagle
# BlueDawn246
# autumn-midnights
# aedgley
# supervchan
# lumosmaqixma
# sasharyder
# Neymovirne
# aedgley
# SiriuslyMaraudeers
# aedgley
# ConstructiveRomance
# Herochick007
# Celestia0909
# Herochick007
# CourtneyEllen
# Nimpark
# Thetiesthatbindus
# ImHollyBlue
# NotVanillaShit
# articcat621
# Herochick007
# articcat621
# Little-Miss-Fujoshi
# HogwartsPrincess89
# softjily
# DobbyRocksSocks
# Vale-Malfoy-Black
# mew-tsubaki
# intheinkpot
# LexSnape
# Sorcerer-s-Muse
# Priestesses-of-H-I-S-S
# Mexxlove
# HP-fans4ever
# KaoticOverlord
# Herochick007
# moonfairy13
# Doristarazona
# tweety-src-clt9
# PlumedeSorbier
# Jem-Doe
# emyjrose
# Ann-Carmesi
# writers-and-ravens
# 1potterhead07
# Clara-Midwinter
# StarsAboveInMyEyes
# Screaming-Faeries
# CinderellaAtTheBall
# Doristarazona
# Ren-Ichimoku-fan1
# Herochick007
# ImHollyBlue
# NinjaDevil2000
# secretfanficlover
# StoriesbyNessie
# poisonrationalitie
# Jem-Doe
# secretfanficlover
# GoldenQuill11
# MagicGirlinAMuggleWorld
# intheinkpot
# Mexxlove
# Rise-Of-The-Fallen-Dragons
# Immortalparadox91
# YakAge
# Amarylle
# Felicia-Vardya
# LadyKenz347
# Rasiaa
# Phinoa
# Smithback
# ImHollyBlue
# Chibi-Shibi
# Juliette54
# Mccrps
# Bumlewis
# FerAmaya
# Mexxlove
# aliasmel1
# supervchan
# intheinkpot
# ReadBooksWriteThings
# thequeenofmalcontent
# Jem-Doe
# chrisk86
# Pleasenotausername
# petals-to-fish
# lovesbitca8
# m-a-q-u-i-r-a
# Nochedeinvierno13-Friki
# WizardWriting
# Natalie-Annick-Malfoy-Granger
# Amai-Star-of-Darkness
# ImHollyBlue
# SlytherinPrincess87
# Gaty
# Cynthia-Reine
# TheElvinDemigodDW2
# grace-lou-freebush
# Nochedeinvierno13-Friki
# thequeenofmalcontent
# mew-tsubaki
# Nochedeinvierno13-Friki
# Lou2U
# Nochedeinvierno13-Friki
# LittleSixx
# Lou2U
# Aneswe
# Shriayle
# otaku-chocolat
# Drarry-fanfic-Reader
# Lucy-Dei
# Dorothea-Greengrass
# iNiGmA
# Imse2003
# LauraElliot
# TheTitaniumSerpent
# Stelmarya
# HoplessAndWandering
# aimeedaralyon
# Smithback
# White-Squirrel
# badgerpride
# Izzy
# J-Jamie-Dupane
# livie375
# Milky01
# Stormgate
# mph1473
# NinjaDevil2000
# NinjaDevil2000
# Hazuzu
# Mansi-jain
# DASTAAN
# VonPelt
# Gabi-Evans
# Pruls
# LadyKenz347
# LadyKenz347
# LadyKenz347
# Liz-Jean-Tonks
# LadyKenz347
# Sakubato
# Samara13
# TheElvinDemigodDW2
# Natalie-Annick-Malfoy-Granger
# zerodawn22
# Sutiibun-Raitobi
# secretfanficlover
# XenaDragon-xoxo
# RodeRozen
# Harley-S-Quinn
# Herochick007
# sweet-little-kaye
# Burls
# Muismiep
# wine-witch
# FI-Hansel-Aaron-Ivar
# raienetta
# lavenderrain2017
# ravenslight
# Dr-Leopold-Fitz
# Adonisia
# regulilystan
# niffizzle
# Claude-Amelia-Song
# crystalovegood
# Jetainia
# Herochick007
# Cheeky-Slytherin-Lass
# reveusebanale
# DarylDixon-sgirl1985
# headcanonsandmore
# secretfanficlover
# Hystaracal
# In-Dreams
# Kyonomiko
# poisonrationalitie
# MrsRen
# LittleSixx
# Lili76
# MoonytheMarauder1
# PenguinofProse
# hollyhobbit101
# megaflash
# hollyhobbit101
# MalenkayaCherepakha
# Tabby-Kitten
# IHateCheddar
# DrinkCocoa
# IRiSEaGLes
# IRiSEaGLes
# HuntressSoul
# HuntressSoul
# aimeedaralyon
# secretfanficlover
# Lor-tan
# Lor-tan
# KatieBY
# KatieBY
# gingerbred
# SocialistBukharin
# Genuka
# B-Weasley
# Onyx-Obsidian
# Shibalyfe
# corvusdraconis
# whitetiger91
# StarsAboveInMyEyes
# Ayolen

# %%
HPData.to_csv("finalHPData.csv", index = False)
